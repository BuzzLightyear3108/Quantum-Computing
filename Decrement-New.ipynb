# %% [markdown]
# <div style='font-size:225%; font-weight:bold; text-align: center'>Quantum Multiplication Calculator Builder</div>
#
# # Abstract
#
# This project is a construction of multiplication calculation calculator with quantum computing processes. It uses qubits, short for quantum bits, and quantum gates, as opposed to classical bits and gates. Quantum bits can simultaneously represent the state of 0 and the state of 1. It is referred to as superposition. Quantum gates, including controlled-not gates (CX or CNOT, CCX or CCNOT, etc.), are special that even its counterparts for AND and XOR gates are also using special quantum gates like RX, RY, RZ gates and Hadamard gate.

# %% [markdown]
# # Introduction
#
# This project is using Qiskit.
#
# Therefore, for more information about how Quantum Gates are implementing their functions using building blocks like Hadamard gates, etc., refer to this <a href='https://qiskit.org/documentation/_modules/qiskit/circuit/library/standard_gates/x.html'>documentation</a>.
#
# License: https://creativecommons.org/licenses/by/4.0/deed.en (Please provide credit for my work)
#
# ## Application
#
# Most likely, multiplication by quantum computing might be used to solve complex equations like derivatives and differentials.
#
# ### Derivatives Applications
# 1. Finding Local and Absolute Maximum and Minimum values
# 2. Optimization Problems
# 3. Newton's Method
#
#
# ### Differential Applications
# 1. Newton's Law of Cooling
# 2. Models of Population Growth
# 3. Trigonometric and Logarithmic Equations
#
# Furthermore, it is also compatible for calculations of trigonometric and logarithmic equations, both computations of their derivatives and the approximations of their sums.
#
#
#
#
# (Information might be updated later.)

# %% [markdown]
# ## Multiplier Hierarchy
#
# Below is a hierarchy of a multiplier example with 2-bit (nbits = 2) showing layers of physical qubits (q0 to q11) being united into logical qubits (q12 to q19), which, in turn, being united into larger logical qubits that are, ultimately, the outputs (q4 to q7).
#
# They are all organized in NAND Gates since they are Sum-of-Products (SOP). Since direct sums using OR gate is not possible in Qiskit quantum computing circuitry, using DeMorgan's Theorem to convert them to NAND Gates might be the alterative to do so.
#
# (Note: Different nbit (number of bits) yield no resemblance with this example below. In other words, a very different hierachy would be produced.)
#
# ![Multiplier%20Hierarchy-2.png](attachment:Multiplier%20Hierarchy-2.png)

# %% [markdown]
# # Import Modules
#
# Import modules, including several Qiskit modules

# %%
from qiskit import QuantumCircuit, Aer, execute, transpile
from qiskit_aer import AerSimulator

from qiskit.circuit import Instruction, CircuitInstruction, Qubit, QuantumRegister, Clbit, ClassicalRegister
from qiskit.circuit.library.standard_gates import XGate, CXGate, CCXGate, C3XGate, C4XGate, MCXGate
from qiskit.exceptions import QiskitError

import matplotlib.pyplot as plt
# %matplotlib inline
from qiskit.visualization import plot_histogram

import os
import sys
import math as m
import numpy as np
import pandas as pd
import sympy

from _functools import *
from traceback import format_exc

# %% [markdown]
# # Define Functions
#
# Functions that are general but customary should be defined. These functions are considered customary since they may or may not be standard functions and methods provided in default by Python.
#
# Here are the functions:
# <ol>
#
# <li>group() function<br>
# <div>
#
# This function can be used for grouping a list into a list of lists with the specified length length of the sublists.<br><br>
# For instance, an array [2, 8, 3, 5, 9] can be grouped into [[2, 8], [3, 5], [9]] if group(array, 2) is called.
#
# However, if the length of the list is not the multiple of the length of the sublists, the last sublist will have the nmber of the remaining items in the original array. In other words, the length of the last sublist will be the remainder of array_length divided by sub_array_length, which can be calculated as follows (also using % modulo operator in Python):
#
# Last_Sub_array_length
#     = (array_length) mod (sub_array_length)
#     = (array_length) % (sub_array_length)
#
# In the example above:
# array_length = 5
# sub_array_length = 2
#
# (array_length) mod (sub_array_length)
#     = (array_length) % (sub_array_length)
#     = 5 % 2
#     = 1
#
# The last array [9] in the grouped array [[2, 8], [3, 5], [9]] has only a length of 1.
# <br><br>
#
# </div>
# </li>
#
# <li>afmtsd() function
# <div>
# "afmtsd" stands for "Add for making the same digits".<br>
# This function can add some letters or numbers to the front for various purposes, including sorting purposes. For example, if one desires to sort an array ['00011', '100'], making '100' (3 digits) to become '00100' (5 digits) can make use of this function by calling afmtsd(['00011', '100'], '0', 5).
# <br><br>
# </div>
# </li>
#
# <li>dstatial() function
# <div>
# "dstatial" stands for "Do something to all things in a list".<br>
# This function is similar if one calls list(map()) function. It means applying a function to all items in the list. This function comes in handy when one does not want to avoid using too many parentheses when calling the list(map()) function.
# </div>
# </li>
#
# </ol>

# %%
def group(list, subListLen):
    if subListLen != 0:
        grouped_list = []
        
        try: len_list = len(list)
        except TypeError as errordesc:
            if repr(errordesc) == 'TypeError("object of type \'int\' has no len()")':
                len_list = subListLen+1
        
        for a in range(0, len_list, int(subListLen)):
            if type(list) == type(0): grouped_list.append('')
            else: grouped_list.append(list[a:a+subListLen])
        
        if grouped_list == []: grouped_list.append('')
        
        return grouped_list
        
    else:
        pass

def afmtsd(the_list_original, chara, ndigits):
    # afmtsd stands for "Add for making the same digits"
    the_list = list(the_list_original)
    a = [chara]*(ndigits-len(the_list)) + the_list
    
    if type(the_list_original) == type(''): return ''.join(a)
    else: return a
      
def dstatial(the_function,the_list):
    # "Do something to all things in a list"
    the_new_list = []
    
    for tla in the_list:
        the_new_list.append(the_function(tla))
        
    return the_new_list

# %% [markdown]
# # All Combinations of Multiplications
#
# Generate a combination of multiplication by classical computing in order to generate the Sum-of-Products (SOP) equation.

# %%
data = [0, 1]

nbits = 4
lendata, digits = len(data), nbits*2

numsList = []
ProductCBinFinals = []

# Create Raw Table List of Lists to be converted to Pandas
# so that it can be printed as tables

# (Note: RawTable is treated as a temporary variable designed only for printing
#       so that it can be replaced later for printing other data)
RawTable = []

for i in range(1, lendata**digits):
    nums = [data[(i//lendata**d)%lendata] for d in range(digits)[::-1]]
    
    nums0 = nums
    
    # Product using Classical Computation
    # (Convert nums0 and nums1, binary number representation, to decimal numbers A and B)
    A = np.sum(2**np.arange(len(nums0))[::-1]*nums0)
    ProductClassical = A - 1
    
    # Convert the Classical Product to its Binary (Base 2) version
    ProductCBin = list(afmtsd(bin(ProductClassical)[2:], '0', digits))
    
    # Finalize the ProductCBin
    ProductCBinFinal = dstatial(int, ProductCBin)

    numsList += [nums]
    ProductCBinFinals += [ProductCBinFinal]
    
    RawTable.append([i, A, nums0, ProductClassical, nums, ProductCBinFinal])

# Maximize Pandas Column Width
pd.set_option('display.max_colwidth', None)

# Create Pandas DataFrame based on RawTable
# (Note: Table is treated as a temporary variable designed only for printing
#       so that it can be replaced later for printing other data)
Table = pd.DataFrame(RawTable, columns=['i', 'A', 'nums0', 'ProductClassical = A * B', 'Input Qubits', 'Output Qubits (ProductCBinFinal)'])

# Align Text Center
Table = Table.style.set_properties(**{'text-align': 'center'})

Table
# Out:
# <style type="text/css">
# #T_3bc05_row0_col0, #T_3bc05_row0_col1, #T_3bc05_row0_col2, #T_3bc05_row0_col3, #T_3bc05_row0_col4, #T_3bc05_row0_col5, #T_3bc05_row1_col0, #T_3bc05_row1_col1, #T_3bc05_row1_col2, #T_3bc05_row1_col3, #T_3bc05_row1_col4, #T_3bc05_row1_col5, #T_3bc05_row2_col0, #T_3bc05_row2_col1, #T_3bc05_row2_col2, #T_3bc05_row2_col3, #T_3bc05_row2_col4, #T_3bc05_row2_col5, #T_3bc05_row3_col0, #T_3bc05_row3_col1, #T_3bc05_row3_col2, #T_3bc05_row3_col3, #T_3bc05_row3_col4, #T_3bc05_row3_col5, #T_3bc05_row4_col0, #T_3bc05_row4_col1, #T_3bc05_row4_col2, #T_3bc05_row4_col3, #T_3bc05_row4_col4, #T_3bc05_row4_col5, #T_3bc05_row5_col0, #T_3bc05_row5_col1, #T_3bc05_row5_col2, #T_3bc05_row5_col3, #T_3bc05_row5_col4, #T_3bc05_row5_col5, #T_3bc05_row6_col0, #T_3bc05_row6_col1, #T_3bc05_row6_col2, #T_3bc05_row6_col3, #T_3bc05_row6_col4, #T_3bc05_row6_col5, #T_3bc05_row7_col0, #T_3bc05_row7_col1, #T_3bc05_row7_col2, #T_3bc05_row7_col3, #T_3bc05_row7_col4, #T_3bc05_row7_col5, #T_3bc05_row8_col0, #T_3bc05_row8_col1, #T_3bc05_row8_col2, #T_3bc05_row8_col3, #T_3bc05_row8_col4, #T_3bc05_row8_col5, #T_3bc05_row9_col0, #T_3bc05_row9_col1, #T_3bc05_row9_col2, #T_3bc05_row9_col3, #T_3bc05_row9_col4, #T_3bc05_row9_col5, #T_3bc05_row10_col0, #T_3bc05_row10_col1, #T_3bc05_row10_col2, #T_3bc05_row10_col3, #T_3bc05_row10_col4, #T_3bc05_row10_col5, #T_3bc05_row11_col0, #T_3bc05_row11_col1, #T_3bc05_row11_col2, #T_3bc05_row11_col3, #T_3bc05_row11_col4, #T_3bc05_row11_col5, #T_3bc05_row12_col0, #T_3bc05_row12_col1, #T_3bc05_row12_col2, #T_3bc05_row12_col3, #T_3bc05_row12_col4, #T_3bc05_row12_col5, #T_3bc05_row13_col0, #T_3bc05_row13_col1, #T_3bc05_row13_col2, #T_3bc05_row13_col3, #T_3bc05_row13_col4, #T_3bc05_row13_col5, #T_3bc05_row14_col0, #T_3bc05_row14_col1, #T_3bc05_row14_col2, #T_3bc05_row14_col3, #T_3bc05_row14_col4, #T_3bc05_row14_col5, #T_3bc05_row15_col0, #T_3bc05_row15_col1, #T_3bc05_row15_col2, #T_3bc05_row15_col3, #T_3bc05_row15_col4, #T_3bc05_row15_col5, #T_3bc05_row16_col0, #T_3bc05_row16_col1, #T_3bc05_row16_col2, #T_3bc05_row16_col3, #T_3bc05_row16_col4, #T_3bc05_row16_col5, #T_3bc05_row17_col0, #T_3bc05_row17_col1, #T_3bc05_row17_col2, #T_3bc05_row17_col3, #T_3bc05_row17_col4, #T_3bc05_row17_col5, #T_3bc05_row18_col0, #T_3bc05_row18_col1, #T_3bc05_row18_col2, #T_3bc05_row18_col3, #T_3bc05_row18_col4, #T_3bc05_row18_col5, #T_3bc05_row19_col0, #T_3bc05_row19_col1, #T_3bc05_row19_col2, #T_3bc05_row19_col3, #T_3bc05_row19_col4, #T_3bc05_row19_col5, #T_3bc05_row20_col0, #T_3bc05_row20_col1, #T_3bc05_row20_col2, #T_3bc05_row20_col3, #T_3bc05_row20_col4, #T_3bc05_row20_col5, #T_3bc05_row21_col0, #T_3bc05_row21_col1, #T_3bc05_row21_col2, #T_3bc05_row21_col3, #T_3bc05_row21_col4, #T_3bc05_row21_col5, #T_3bc05_row22_col0, #T_3bc05_row22_col1, #T_3bc05_row22_col2, #T_3bc05_row22_col3, #T_3bc05_row22_col4, #T_3bc05_row22_col5, #T_3bc05_row23_col0, #T_3bc05_row23_col1, #T_3bc05_row23_col2, #T_3bc05_row23_col3, #T_3bc05_row23_col4, #T_3bc05_row23_col5, #T_3bc05_row24_col0, #T_3bc05_row24_col1, #T_3bc05_row24_col2, #T_3bc05_row24_col3, #T_3bc05_row24_col4, #T_3bc05_row24_col5, #T_3bc05_row25_col0, #T_3bc05_row25_col1, #T_3bc05_row25_col2, #T_3bc05_row25_col3, #T_3bc05_row25_col4, #T_3bc05_row25_col5, #T_3bc05_row26_col0, #T_3bc05_row26_col1, #T_3bc05_row26_col2, #T_3bc05_row26_col3, #T_3bc05_row26_col4, #T_3bc05_row26_col5, #T_3bc05_row27_col0, #T_3bc05_row27_col1, #T_3bc05_row27_col2, #T_3bc05_row27_col3, #T_3bc05_row27_col4, #T_3bc05_row27_col5, #T_3bc05_row28_col0, #T_3bc05_row28_col1, #T_3bc05_row28_col2, #T_3bc05_row28_col3, #T_3bc05_row28_col4, #T_3bc05_row28_col5, #T_3bc05_row29_col0, #T_3bc05_row29_col1, #T_3bc05_row29_col2, #T_3bc05_row29_col3, #T_3bc05_row29_col4, #T_3bc05_row29_col5, #T_3bc05_row30_col0, #T_3bc05_row30_col1, #T_3bc05_row30_col2, #T_3bc05_row30_col3, #T_3bc05_row30_col4, #T_3bc05_row30_col5, #T_3bc05_row31_col0, #T_3bc05_row31_col1, #T_3bc05_row31_col2, #T_3bc05_row31_col3, #T_3bc05_row31_col4, #T_3bc05_row31_col5, #T_3bc05_row32_col0, #T_3bc0 ...

# %% [markdown]
# Then, use Sympy Module to organize the SOP from a Dictionary.<br><br>
# Here is an example that is similar to the one mentioned in a <a href='https://docs.sympy.org/latest/modules/logic.html#sympy.logic.boolalg.SOPform'>Sympy documentation page about SOP.</a>

# %%
w,x,y,z = sympy.symbols('w,x,y,z')
minterms = [{w: 0, x: 1}, {y: 1, z: 1, x: 0}]
sympy.SOPform([w, x, y, z], minterms)
# Out:
# (x & ~w) | (y & z & ~x)

# %% [markdown]
# # Convert SOP to Quantum Circuit
#
# Here is an important function used to convert SOP to Quantum Circuit:
#
# <table align='left'>
#
# <tr>
# <th style="text-align: left">Method</th>
# <th style="text-align: left">Purpose</th>
# </tr>
#
# <tr>
# <td style="text-align: left">Sympy atoms() method</td>
# <td style="text-align: left">Method of Sympy SOPform object to split by a Conjunction
#     to split AND project</td>
# </tr>
#
# </table>

# %%
ProductCBinFinalsArr = np.array(ProductCBinFinals)
ProductCBinColNum = ProductCBinFinalsArr.shape[1]

termsCompr1 = []
prodinSOPLen = []

qubitNums = digits*2 + ProductCBinColNum

# Create Raw Table List of Lists to be converted to Pandas
# so that it can be printed as tables
RawTable = []

for i in range(ProductCBinColNum):
    ProductArr = ProductCBinFinalsArr[:, i]
    ProductArr1Indices = np.arange(len(ProductArr))[ProductArr == 1]

    # numsArr contains every possible combinations of input states, whether YES or NO
    # ProductArr1Inputs contain the inputs only if they make Product output = 1
    numsArr = np.array(numsList)
    ProductArr1Inputs = numsArr[ProductArr1Indices]

    # Determine how many Input (num of cols in from the table)
    inputNums = ProductArr1Inputs.shape[1]

    ProductRawEq1 = []
    symbols = [sympy.Symbol('q%s' % QubitIndex) for QubitIndex in range(inputNums)]

    for ProductArr1InputsCont in ProductArr1Inputs:
        ProductRawEq1 += [[{symbols[inputIndex]:ProductArr1InputsCont[inputIndex] for inputIndex in range(len(ProductArr1InputsCont))}]]

    ProductRawEq2 = np.array(ProductRawEq1)
    ProductRawEq3 = ProductRawEq2.flatten().tolist()

    SOP = sympy.SOPform(symbols, ProductRawEq3)
    SOPProducts = SOP.atoms(sympy.And)

    SOP_NAND = bool(1)
    
    for SOPProduct in SOPProducts:
        SOP_NAND &= ~SOPProduct
    
    SOP_NAND = ~SOP_NAND
    
    termsList = [tuple(str(SOPProduct).split(' & ')) for SOPProduct in SOPProducts]
    termsCompr1.extend(termsList)
    prodinSOPLen.append(len(termsList))
    
    RawTable.append([f'q{i+digits}', SOP_NAND])

# Maximize Pandas Column Width
pd.set_option('display.max_colwidth', None)

# Create Pandas DataFrame based on RawTable
Table = pd.DataFrame(RawTable, columns=['Output Qubits', 'Boolean/Logical Equations'])

# Align Text leftmost
Table = Table.style.set_properties(**{'text-align': 'left'})

# Align Table Header leftmost
Table = Table.set_table_styles([dict(selector = 'th', props=[('text-align', 'center')])])

Table
# Out:
# <style type="text/css">
# #T_06433 th {
#   text-align: center;
# }
# #T_06433_row0_col0, #T_06433_row0_col1, #T_06433_row1_col0, #T_06433_row1_col1, #T_06433_row2_col0, #T_06433_row2_col1, #T_06433_row3_col0, #T_06433_row3_col1, #T_06433_row4_col0, #T_06433_row4_col1, #T_06433_row5_col0, #T_06433_row5_col1, #T_06433_row6_col0, #T_06433_row6_col1, #T_06433_row7_col0, #T_06433_row7_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_06433">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06433_level0_col0" class="col_heading level0 col0" >Output Qubits</th>
#       <th id="T_06433_level0_col1" class="col_heading level0 col1" >Boolean/Logical Equations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06433_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06433_row0_col0" class="data row0 col0" >q8</td>
#       <td id="T_06433_row0_col1" class="data row0 col1" >~(~(q0 & q1) & ~(q0 & q2) & ~(q0 & q3) & ~(q0 & q4) & ~(q0 & q5) & ~(q0 & q6) & ~(q0 & q7))</td>
#     </tr>
#     <tr>
#       <th id="T_06433_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06433_row1_col0" class="data row1 col0" >q9</td>
#       <td id="T_06433_row1_col1" class="data row1 col1" >~(~(q1 & q2) & ~(q1 & q3) & ~(q1 & q4) & ~(q1 & q5) & ~(q1 & q6) & ~(q1 & q7) & ~(q0 & ~q1 & ~q2 & ~q3 & ~q4 & ~q5 & ~q6 & ~q7))</td>
#     </tr>
#     <tr>
#       <th id="T_06433_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_06433_row2_col0" class="data row2 col0" >q10</td>
#       <td id="T_06433_row2_col1" class="data row2 col1" >~(~(q2 & q3) & ~(q2 & q4) & ~(q2 & q5) & ~(q2 & q6) & ~(q2 & q7) & ~(q0 & ~q2 & ~q3 & ~q4 & ~q5 & ~q6 & ~q7) & ~(q1 & ~q2 & ~q3 & ~q4 & ~q5 & ~q6 & ~q7))</td>
#     </tr>
#     <tr>
#       <th id="T_06433_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_06433_row3_col0" class="data row3 col0" >q11</td>
#       <td id="T_06433_row3_col1" class="data row3 col1" >~(~(q3 & q4) & ~(q3 & q5) & ~(q3 & q6) & ~(q3 & q7) & ~(q0 & ~q3 & ~q4 & ~q5 & ~q6 & ~q7) & ~(q1 & ~q3 & ~q4 & ~q5 & ~q6 & ~q7) & ~(q2 & ~q3 & ~q4 & ~q5 & ~q6 & ~q7))</td>
#     </tr>
#     <tr>
#       <th id="T_06433_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_06433_row4_col0" class="data row4 col0" >q12</td>
#       <td id="T_06433_row4_col1" class="data row4 col1" >~(~(q4 & q5) & ~(q4 & q6) & ~(q4 & q7) & ~(q0 & ~q4 & ~q5 & ~q6 & ~q7) & ~(q1 & ~q4 & ~q5 & ~q6 & ~q7) & ~(q2 & ~q4 & ~q5 & ~q6 & ~q7) & ~(q3 & ~q4 & ~q5 & ~q6 & ~q7))</td>
#     </tr>
#     <tr>
#       <th id="T_06433_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_06433_row5_col0" class="data row5 col0" >q13</td>
#       <td id="T_06433_row5_col1" class="data row5 col1" >~(~(q5 & q6) & ~(q5 & q7) & ~(q0 & ~q5 & ~q6 & ~q7) & ~(q1 & ~q5 & ~q6 & ~q7) & ~(q2 & ~q5 & ~q6 & ~q7) & ~(q3 & ~q5 & ~q6 & ~q7) & ~(q4 & ~q5 & ~q6 & ~q7))</td>
#     </tr>
#     <tr>
#       <th id="T_06433_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_06433_row6_col0" class="data row6 col0" >q14</td>
#       <td id="T_06433_row6_col1" class="data row6 col1" >~(~(q6 & q7) & ~(q0 & ~q6 & ~q7) & ~(q1 & ~q6 & ~q7) & ~(q2 & ~q6 & ~q7) & ~(q3 & ~q6 & ~q7) & ~(q4 & ~q6 & ~q7) & ~(q5 & ~q6 & ~q7))</td>
#     </tr>
#     <tr>
#       <th id="T_06433_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_06433_row7_col0" class="data row7 col0" >q15</td>
#       <td id="T_06433_row7_col1" class="data row7 col1" >~(~(q0 & ~q7) & ~(q1 & ~q7) & ~(q2 & ~q7) & ~(q3 & ~q7) & ~(q4 & ~q7) & ~(q5 & ~q7) & ~(q6 & ~q7))</td>
#     </tr>
#   </tbody>
# </table>

# %%
termsCompr2 = []

# Create Raw Table List of Lists to be converted to Pandas
# so that it can be printed as tables
RawTable = []

for termsCompr1Cont in termsCompr1:
    if termsCompr1Cont not in termsCompr2:
        termsCompr2.append(termsCompr1Cont)
    
        RawTable.append([termsCompr1Cont])

# Maximize Pandas Column Width
pd.set_option('display.max_colwidth', None)

# Create Pandas DataFrame based on RawTable
Table = pd.DataFrame(RawTable, columns=['Inner Logical Qubits'])

# Align Text leftmost
TableStyle1 = Table.style.set_properties(**{'text-align': 'left'})

# Count the number "Logical" Qubits (groups of Physical Qubits: q12 to q19)
# (It is shown in the hierachy on the top of this Notebook with nbits = 2 as an example)
Table.loc['Count'] = Table[['Inner Logical Qubits']].count()

qubitNumsInitial = qubitNums

qubitNums += len(termsCompr2)

print('Number of Qubits:', qubitNums)

Table

#termsCompr2, len(termsCompr2)
# Out:
# Number of Qubits: 80
#                           Inner Logical Qubits
# 0                                     (q0, q3)
# 1                                     (q0, q5)
# 2                                     (q0, q2)
# 3                                     (q0, q6)
# 4                                     (q0, q4)
# 5                                     (q0, q7)
# 6                                     (q0, q1)
# 7                                     (q1, q6)
# 8                                     (q1, q4)
# 9                                     (q1, q7)
# 10     (q0, ~q1, ~q2, ~q3, ~q4, ~q5, ~q6, ~q7)
# 11                                    (q1, q2)
# 12                                    (q1, q3)
# 13                                    (q1, q5)
# 14                                    (q2, q5)
# 15                                    (q2, q6)
# 16                                    (q2, q4)
# 17                                    (q2, q7)
# 18          (q1, ~q2, ~q3, ~q4, ~q5, ~q6, ~q7)
# 19          (q0, ~q2, ~q3, ~q4, ~q5, ~q6, ~q7)
# 20                                    (q2, q3)
# 21                                    (q3, q5)
# 22                                    (q3, q6)
# 23                                    (q3, q4)
# 24                                    (q3, q7)
# 25               (q0, ~q3, ~q4, ~q5, ~q6, ~q7)
# 26               (q1, ~q3, ~q4, ~q5, ~q6, ~q7)
# 27               (q2, ~q3, ~q4, ~q5, ~q6, ~q7)
# 28                                    (q4, q5)
# 29                                    (q4, q6)
# 30                                    (q4, q7)
# 31                    (q3, ~q4, ~q5, ~q6, ~q7)
# 32                    (q1, ~q4, ~q5, ~q6, ~q7)
# 33                    (q2, ~q4, ~q5, ~q6, ~q7)
# 34                    (q0, ~q4, ~q5, ~q6, ~q7)
# 35                                    (q5, q6)
# 36                         (q1, ~q5, ~q6, ~q7)
# 37                         (q3, ~q5, ~q6, ~q7)
# 38                                    (q5, q7)
# 39                         (q2, ~q5, ~q6, ~q7)
# 40                         (q4, ~q5, ~q6, ~q7)
# 41                         (q0, ~q5, ~q6, ~q7)
# 42                              (q1, ~q6, ~q7)
# 43                              (q3, ~q6, ~q7)
# 44                              (q2, ~q6, ~q7)
# 45                              (q5, ~q6, ~q7)
# 46                                    (q6, q7)
# 47                              (q0, ~q6, ~q7)
# 48                              (q4, ~q6, ~q7)
# 49                                   (q1, ~q7)
# 50                                   (q3, ~q7)
# 51                                   (q4, ~q7)
# 52                                   (q5, ~q7)
# 53                                   (q0, ~q7)
# 54                                   (q2, ~q7)
# 55                                   (q6, ~q7)
# Count                                       56

# %% [markdown]
# ## Organizing by Preparing for the First Layer
#
# Here is another important function used to convert SOP to Quantum Circuit:
#
# <table align='left'>
#
# <tr>
# <th style="text-align: left">Method</th>
# <th style="text-align: left">Purpose</th>
# </tr>
#
# <tr>
# <td style="text-align: left">str.split()</td>
# <td style="text-align: left">Method of str object to split by letter "q"<br>
#     It is the easiest to do so since it is the only separation between "~" symbol (if any) and the qubit number.</td>
# </tr>
#
# </table>

# %%
termsCompr3 = []

for termsCompr2Index in range(len(termsCompr2)):
    targetQubit = (termsCompr2Index+qubitNumsInitial,)

    # MCXG stands for MCXGate, which is a multiple-qubit-controlled CNOT or CX Gate
    QubitMCXGCommand = ()

    for controlQubit in termsCompr2[termsCompr2Index]:
        controlQubitProfile = controlQubit.split('q')

        # If controlQubitProfile[0] == '':
            # then controlQubit is not inverted
            # Note: '' converted to boolean is False

        if controlQubitProfile[0]:
            controlQubitProfile = int(controlQubitProfile[1])+digits*2

        else:
            controlQubitProfile = int(controlQubitProfile[1])

        QubitMCXGCommand += (controlQubitProfile,) # tuple can only be concatenated, not appended

    termsCompr3.append(QubitMCXGCommand+targetQubit)
    
print(termsCompr3)
# Out:
# [(0, 3, 24), (0, 5, 25), (0, 2, 26), (0, 6, 27), (0, 4, 28), (0, 7, 29), (0, 1, 30), (1, 6, 31), (1, 4, 32), (1, 7, 33), (0, 17, 18, 19, 20, 21, 22, 23, 34), (1, 2, 35), (1, 3, 36), (1, 5, 37), (2, 5, 38), (2, 6, 39), (2, 4, 40), (2, 7, 41), (1, 18, 19, 20, 21, 22, 23, 42), (0, 18, 19, 20, 21, 22, 23, 43), (2, 3, 44), (3, 5, 45), (3, 6, 46), (3, 4, 47), (3, 7, 48), (0, 19, 20, 21, 22, 23, 49), (1, 19, 20, 21, 22, 23, 50), (2, 19, 20, 21, 22, 23, 51), (4, 5, 52), (4, 6, 53), (4, 7, 54), (3, 20, 21, 22, 23, 55), (1, 20, 21, 22, 23, 56), (2, 20, 21, 22, 23, 57), (0, 20, 21, 22, 23, 58), (5, 6, 59), (1, 21, 22, 23, 60), (3, 21, 22, 23, 61), (5, 7, 62), (2, 21, 22, 23, 63), (4, 21, 22, 23, 64), (0, 21, 22, 23, 65), (1, 22, 23, 66), (3, 22, 23, 67), (2, 22, 23, 68), (5, 22, 23, 69), (6, 7, 70), (0, 22, 23, 71), (4, 22, 23, 72), (1, 23, 73), (3, 23, 74), (4, 23, 75), (5, 23, 76), (0, 23, 77), (2, 23, 78), (6, 23, 79)]

# %% [markdown]
# ## Define print_exec() as a combination between exec() and print()
#
# <table align='left'>
#
# <tr>
# <td style="text-align: left">print() function</td>
# <td style="text-align: left">For printing the command</td>
# </tr>
#
# <tr>
# <td style="text-align: left">exec() function</td>
# <td style="text-align: left">For executing the command from strings</td>
# </tr>
#
# </table>

# %%
def print_exec(command, sep=' ', end='\n'):
    print(command, sep=sep, end=end)
    exec(command)

# %% [markdown]
# # Create a Quantum Circuit
#
# ## mCirc stands for "Multiplier Circuit"

# %%
mCirc = QuantumCircuit(qubitNums, digits)

# %% [markdown]
# ## Create Inverse Qubits

# %%
for InputNum in range(digits):
    inverseInputNum = InputNum+digits*2 
    print_exec(f'mCirc.cx({InputNum}, {inverseInputNum})')
    print_exec(f'mCirc.x({inverseInputNum})')
# Out:
# mCirc.cx(0, 16)
# mCirc.x(16)
# mCirc.cx(1, 17)
# mCirc.x(17)
# mCirc.cx(2, 18)
# mCirc.x(18)
# mCirc.cx(3, 19)
# mCirc.x(19)
# mCirc.cx(4, 20)
# mCirc.x(20)
# mCirc.cx(5, 21)
# mCirc.x(21)
# mCirc.cx(6, 22)
# mCirc.x(22)
# mCirc.cx(7, 23)
# mCirc.x(23)

# %% [markdown]
# # Simplify by organizing several qubits onto one
#
# ## Creation of Inner Layer of Logical Qubits

# %%
operationSOP1 = []
operationSOP1Checkpoint = 0
    
for operationSOP1Index in prodinSOPLen:
    slicedTerms = termsCompr3[operationSOP1Checkpoint:operationSOP1Checkpoint+operationSOP1Index]
    
    operationSOP1.append(slicedTerms)
    operationSOP1Checkpoint += operationSOP1Index

print(prodinSOPLen, end='\n\n\n')
print(operationSOP1, end='\n\n\n')
# Out:
# [7, 7, 7, 7, 7, 7, 7, 7]
#
#
# [[(0, 3, 24), (0, 5, 25), (0, 2, 26), (0, 6, 27), (0, 4, 28), (0, 7, 29), (0, 1, 30)], [(1, 6, 31), (1, 4, 32), (1, 7, 33), (0, 17, 18, 19, 20, 21, 22, 23, 34), (1, 2, 35), (1, 3, 36), (1, 5, 37)], [(2, 5, 38), (2, 6, 39), (2, 4, 40), (2, 7, 41), (1, 18, 19, 20, 21, 22, 23, 42), (0, 18, 19, 20, 21, 22, 23, 43), (2, 3, 44)], [(3, 5, 45), (3, 6, 46), (3, 4, 47), (3, 7, 48), (0, 19, 20, 21, 22, 23, 49), (1, 19, 20, 21, 22, 23, 50), (2, 19, 20, 21, 22, 23, 51)], [(4, 5, 52), (4, 6, 53), (4, 7, 54), (3, 20, 21, 22, 23, 55), (1, 20, 21, 22, 23, 56), (2, 20, 21, 22, 23, 57), (0, 20, 21, 22, 23, 58)], [(5, 6, 59), (1, 21, 22, 23, 60), (3, 21, 22, 23, 61), (5, 7, 62), (2, 21, 22, 23, 63), (4, 21, 22, 23, 64), (0, 21, 22, 23, 65)], [(1, 22, 23, 66), (3, 22, 23, 67), (2, 22, 23, 68), (5, 22, 23, 69), (6, 7, 70), (0, 22, 23, 71), (4, 22, 23, 72)], [(1, 23, 73), (3, 23, 74), (4, 23, 75), (5, 23, 76), (0, 23, 77), (2, 23, 78), (6, 23, 79)]]

# %% [markdown]
# ### Qiskit Implementation

# %%
for operationSOP1Cont in operationSOP1:
    for SOPProduct in operationSOP1Cont:
        print_exec(f'mCirc.append(MCXGate(num_ctrl_qubits={len(SOPProduct)-1}), {SOPProduct})')
        print_exec(f'mCirc.x({SOPProduct[-1]})', end='\n\n')
        
    print()
# Out:
# mCirc.append(MCXGate(num_ctrl_qubits=2), (0, 3, 24))
# mCirc.x(24)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (0, 5, 25))
# mCirc.x(25)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (0, 2, 26))
# mCirc.x(26)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (0, 6, 27))
# mCirc.x(27)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (0, 4, 28))
# mCirc.x(28)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (0, 7, 29))
# mCirc.x(29)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (0, 1, 30))
# mCirc.x(30)
#
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (1, 6, 31))
# mCirc.x(31)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (1, 4, 32))
# mCirc.x(32)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (1, 7, 33))
# mCirc.x(33)
#
# mCirc.append(MCXGate(num_ctrl_qubits=8), (0, 17, 18, 19, 20, 21, 22, 23, 34))
# mCirc.x(34)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (1, 2, 35))
# mCirc.x(35)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (1, 3, 36))
# mCirc.x(36)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (1, 5, 37))
# mCirc.x(37)
#
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (2, 5, 38))
# mCirc.x(38)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (2, 6, 39))
# mCirc.x(39)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (2, 4, 40))
# mCirc.x(40)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (2, 7, 41))
# mCirc.x(41)
#
# mCirc.append(MCXGate(num_ctrl_qubits=7), (1, 18, 19, 20, 21, 22, 23, 42))
# mCirc.x(42)
#
# mCirc.append(MCXGate(num_ctrl_qubits=7), (0, 18, 19, 20, 21, 22, 23, 43))
# mCirc.x(43)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (2, 3, 44))
# mCirc.x(44)
#
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (3, 5, 45))
# mCirc.x(45)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (3, 6, 46))
# mCirc.x(46)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (3, 4, 47))
# mCirc.x(47)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (3, 7, 48))
# mCirc.x(48)
#
# mCirc.append(MCXGate(num_ctrl_qubits=6), (0, 19, 20, 21, 22, 23, 49))
# mCirc.x(49)
#
# mCirc.append(MCXGate(num_ctrl_qubits=6), (1, 19, 20, 21, 22, 23, 50))
# mCirc.x(50)
#
# mCirc.append(MCXGate(num_ctrl_qubits=6), (2, 19, 20, 21, 22, 23, 51))
# mCirc.x(51)
#
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (4, 5, 52))
# mCirc.x(52)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (4, 6, 53))
# mCirc.x(53)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (4, 7, 54))
# mCirc.x(54)
#
# mCirc.append(MCXGate(num_ctrl_qubits=5), (3, 20, 21, 22, 23, 55))
# mCirc.x(55)
#
# mCirc.append(MCXGate(num_ctrl_qubits=5), (1, 20, 21, 22, 23, 56))
# mCirc.x(56)
#
# mCirc.append(MCXGate(num_ctrl_qubits=5), (2, 20, 21, 22, 23, 57))
# mCirc.x(57)
#
# mCirc.append(MCXGate(num_ctrl_qubits=5), (0, 20, 21, 22, 23, 58))
# mCirc.x(58)
#
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (5, 6, 59))
# mCirc.x(59)
#
# mCirc.append(MCXGate(num_ctrl_qubits=4), (1, 21, 22, 23, 60))
# mCirc.x(60)
#
# mCirc.append(MCXGate(num_ctrl_qubits=4), (3, 21, 22, 23, 61))
# mCirc.x(61)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (5, 7, 62))
# mCirc.x(62)
#
# mCirc.append(MCXGate(num_ctrl_qubits=4), (2, 21, 22, 23, 63))
# mCirc.x(63)
#
# mCirc.append(MCXGate(num_ctrl_qubits=4), (4, 21, 22, 23, 64))
# mCirc.x(64)
#
# mCirc.append(MCXGate(num_ctrl_qubits=4), (0, 21, 22, 23, 65))
# mCirc.x(65)
#
#
# mCirc.append(MCXGate(num_ctrl_qubits=3), (1, 22, 23, 66))
# mCirc.x(66)
#
# mCirc.append(MCXGate(num_ctrl_qubits=3), (3, 22, 23, 67))
# mCirc.x(67)
#
# mCirc.append(MCXGate(num_ctrl_qubits=3), (2, 22, 23, 68))
# mCirc.x(68)
#
# mCirc.append(MCXGate(num_ctrl_qubits=3), (5, 22, 23, 69))
# mCirc.x(69)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (6, 7, 70))
# mCirc.x(70)
#
# mCirc.append(MCXGate(num_ctrl_qubits=3), (0, 22, 23, 71))
# mCirc.x(71)
#
# mCirc.append(MCXGate(num_ctrl_qubits=3), (4, 22, 23, 72))
# mCirc.x(72)
#
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (1, 23, 73))
# mCirc.x(73)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (3, 23, 74))
# mCirc.x(74)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (4, 23, 75))
# mCirc.x(75)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (5, 23, 76))
# mCirc.x(76)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (0, 23, 77))
# mCirc.x(77)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (2, 23, 78))
# mCirc.x(78)
#
# mCirc.append(MCXGate(num_ctrl_qubits=2), (6, 23, 79))
# mCirc.x(79)

# %% [markdown]
# ## Creation of Outer Layer of Logical Qubits (Output Qubits)

# %%
operationSOP2 = []

for operationSOP1Index in range(len(operationSOP1)):
    operationSOP1Cont = operationSOP1[operationSOP1Index]
    
    opSOP1ControlQubits = tuple(operationSOP1aCont[-1] for operationSOP1aCont in operationSOP1Cont)
    opSOP1TargetQubits = (operationSOP1Index+digits,)

    operationSOP2Cont = opSOP1ControlQubits + opSOP1TargetQubits
    operationSOP2.append(operationSOP2Cont)

print(operationSOP2, end='\n\n\n')
# Out:
# [(24, 25, 26, 27, 28, 29, 30, 8), (31, 32, 33, 34, 35, 36, 37, 9), (38, 39, 40, 41, 42, 43, 44, 10), (45, 46, 47, 48, 49, 50, 51, 11), (52, 53, 54, 55, 56, 57, 58, 12), (59, 60, 61, 62, 63, 64, 65, 13), (66, 67, 68, 69, 70, 71, 72, 14), (73, 74, 75, 76, 77, 78, 79, 15)]

# %% [markdown]
# ### Qiskit Implementation

# %%
for operationSOP2Cont in operationSOP2:
    print_exec(f'mCirc.append(MCXGate(num_ctrl_qubits={len(operationSOP2Cont)-1}), {operationSOP2Cont})')
    print_exec(f'mCirc.x({operationSOP2Cont[-1]})', end='\n\n')
# Out:
# mCirc.append(MCXGate(num_ctrl_qubits=7), (24, 25, 26, 27, 28, 29, 30, 8))
# mCirc.x(8)
#
# mCirc.append(MCXGate(num_ctrl_qubits=7), (31, 32, 33, 34, 35, 36, 37, 9))
# mCirc.x(9)
#
# mCirc.append(MCXGate(num_ctrl_qubits=7), (38, 39, 40, 41, 42, 43, 44, 10))
# mCirc.x(10)
#
# mCirc.append(MCXGate(num_ctrl_qubits=7), (45, 46, 47, 48, 49, 50, 51, 11))
# mCirc.x(11)
#
# mCirc.append(MCXGate(num_ctrl_qubits=7), (52, 53, 54, 55, 56, 57, 58, 12))
# mCirc.x(12)
#
# mCirc.append(MCXGate(num_ctrl_qubits=7), (59, 60, 61, 62, 63, 64, 65, 13))
# mCirc.x(13)
#
# mCirc.append(MCXGate(num_ctrl_qubits=7), (66, 67, 68, 69, 70, 71, 72, 14))
# mCirc.x(14)
#
# mCirc.append(MCXGate(num_ctrl_qubits=7), (73, 74, 75, 76, 77, 78, 79, 15))
# mCirc.x(15)

# %% [markdown]
# ### Qubit Measurement
#
# "Measure a quantum bit (qubit) in the Z basis into a classical bit (cbit)."
#
# (Source: https://qiskit.org/documentation/stubs/qiskit.circuit.QuantumCircuit.html#qiskit.circuit.QuantumCircuit.measure)

# %%
mCirc.measure(np.arange(digits)+digits, range(digits)[::-1])

# %% [markdown]
# # Determine Input Value (Either 0 or 1)
#
# ## Initialization Gates
#
# First, zero it out at the beginning.<br>
# All qubits start from ground state |0>. Create manipulable initialization gates as many as the input qubits.<br>
# The identity gate means that it remains the same state as previous, which, in this case, the ground state |0>.
# <br><br>
# Later, the Identity gate can be converted to an X Gate or NOT gate.

# %%
# Determine whether new Initialization Gates are needed to be inserted or not
inputDet = sum([circInst.operation.name == 'x' or circInst.operation.name == 'id' for circInst in mCirc.data[:digits]]) == digits

# If the Initialization Gates do not exists or are incomplete, then insert them.
if inputDet < digits:
    initGates = []
    qreg = mCirc.data[0].qubits[0].register

    for inputIndex in range(digits):
        initGates.append(CircuitInstruction(operation=Instruction(name='id', num_qubits=1, num_clbits=0, params=[]),
                                           qubits=(Qubit(qreg, inputIndex),),
                                           clbits=()))

    mCirc.data = initGates + mCirc.data

mCirc.draw(output='mpl')
# Out:
# C:\Users\mulia\AppData\Local\Temp\ipykernel_39068\1908320097.py:7: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.register`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   qreg = mCirc.data[0].qubits[0].register

# %% [markdown]
# If 0: Apply IGate (since Qubits start at Ground State or 0)<br>
# If 1: Apply XGate<br>
# <br>
# Then, put the XGates and/or IGates in front of all other instructions so that they would be implemented first.

# %% [markdown]
# ### Backends used
#
# Furthermore, there are 2 types of backends, which are quantum computing simulators and real quantum computers:
#
# <table align='left'>
#
# <tr>
# <th style="text-align: left">Backend Name</th>
# <th style="text-align: left">Capability</th>
# </tr>
#
# <tr>
# <td style="text-align: left">qasm_simulator</td>
# <td style="text-align: left">Implementations only with lower memory usage</td>
# </tr>
#
# <tr>
# <td style="text-align: left">matrix_product_state Simulator</td>
# <td style="text-align: left">Implementations with higher memory usage</td>
# </tr>
#
# </table>

# %% [markdown]
# Finally, check whether the classical computing multiplications are <u><b>exactly</b></u> the same with their quantum counterpart.

# %%
backends = [Aer.get_backend('qasm_simulator'),
              AerSimulator(method='matrix_product_state')]

# %% [markdown]
# ### Implement the Program with Combinations of Input States
#
# Here, matrix_product_state Simulator is used since it can implement with higher memory usage

# %%
# Create Raw Table List of Lists to be converted to Pandas
# so that it can be printed as tables
RawTable = []

try:
    backend = backends[1]

    for i in range(1, lendata**digits):
        nums = []
        inputDet = []

        for d, inputIndex in zip(range(digits)[::-1], range(digits)):
            # Binary Input
            BinInput = data[(i//lendata**d)%lendata]

            nums.append(BinInput)

            # BinInput can be 0 or 1, translating to "i" or "x", respectively
            name = ['id', 'x'][BinInput]

            mCirc.data[inputIndex].operation.name = name

        nums0 = nums

        # Product using Classical Computation
        A = np.sum(2**np.arange(len(nums0))[::-1]*nums0)
        ProductClassical = A - 1

        ProductCBin = list(afmtsd(bin(ProductClassical)[2:], '0', digits))
        ProductCBinFinal = dstatial(int, ProductCBin)

        result = execute(mCirc, backend=backend).result()
        counts = result.get_counts()

        countsFinal = dstatial(int, list(list(counts)[0]))
        countsFinalNp = np.array(countsFinal)

        Product_mCirc = np.sum(2**np.arange(digits)[::-1]*countsFinalNp)
    
        RawTable.append([i, A, nums0, ProductCBinFinal, countsFinal, Product_mCirc, np.array(ProductCBinFinal) == countsFinalNp])

        # Maximize Pandas Column Width
        pd.set_option('display.max_colwidth', None)

        # Create Pandas DataFrame based on RawTable
        Table = pd.DataFrame(RawTable, columns=['i', 'A', 'nums0', 'ProductCBinFinal', 'countsFinal', 'Product_mCirc', 'np.array(ProductCBinFinal) == countsFinalNp'])

        # Align Text leftmost
        Table = Table.style.set_properties(**{'text-align': 'left'})

        # Align Table Header leftmost
        Table = Table.set_table_styles([dict(selector = 'th', props=[('text-align', 'center')])])
        
except QiskitError:
    # Get error message by using traceback.format_exc()
    errmsg = format_exc()
    
    # If the error is really Insufficient memory problem, then output it using file=sys.stderr in the print() function
    if "ERROR: Insufficient memory to run circuit circuit-120 using the statevector simulator." in errmsg:
        print('\n'+errmsg, file=sys.stderr)
        
Table
# Out:
# <style type="text/css">
# #T_7f18f th {
#   text-align: center;
# }
# #T_7f18f_row0_col0, #T_7f18f_row0_col1, #T_7f18f_row0_col2, #T_7f18f_row0_col3, #T_7f18f_row0_col4, #T_7f18f_row0_col5, #T_7f18f_row0_col6, #T_7f18f_row1_col0, #T_7f18f_row1_col1, #T_7f18f_row1_col2, #T_7f18f_row1_col3, #T_7f18f_row1_col4, #T_7f18f_row1_col5, #T_7f18f_row1_col6, #T_7f18f_row2_col0, #T_7f18f_row2_col1, #T_7f18f_row2_col2, #T_7f18f_row2_col3, #T_7f18f_row2_col4, #T_7f18f_row2_col5, #T_7f18f_row2_col6, #T_7f18f_row3_col0, #T_7f18f_row3_col1, #T_7f18f_row3_col2, #T_7f18f_row3_col3, #T_7f18f_row3_col4, #T_7f18f_row3_col5, #T_7f18f_row3_col6, #T_7f18f_row4_col0, #T_7f18f_row4_col1, #T_7f18f_row4_col2, #T_7f18f_row4_col3, #T_7f18f_row4_col4, #T_7f18f_row4_col5, #T_7f18f_row4_col6, #T_7f18f_row5_col0, #T_7f18f_row5_col1, #T_7f18f_row5_col2, #T_7f18f_row5_col3, #T_7f18f_row5_col4, #T_7f18f_row5_col5, #T_7f18f_row5_col6, #T_7f18f_row6_col0, #T_7f18f_row6_col1, #T_7f18f_row6_col2, #T_7f18f_row6_col3, #T_7f18f_row6_col4, #T_7f18f_row6_col5, #T_7f18f_row6_col6, #T_7f18f_row7_col0, #T_7f18f_row7_col1, #T_7f18f_row7_col2, #T_7f18f_row7_col3, #T_7f18f_row7_col4, #T_7f18f_row7_col5, #T_7f18f_row7_col6, #T_7f18f_row8_col0, #T_7f18f_row8_col1, #T_7f18f_row8_col2, #T_7f18f_row8_col3, #T_7f18f_row8_col4, #T_7f18f_row8_col5, #T_7f18f_row8_col6, #T_7f18f_row9_col0, #T_7f18f_row9_col1, #T_7f18f_row9_col2, #T_7f18f_row9_col3, #T_7f18f_row9_col4, #T_7f18f_row9_col5, #T_7f18f_row9_col6, #T_7f18f_row10_col0, #T_7f18f_row10_col1, #T_7f18f_row10_col2, #T_7f18f_row10_col3, #T_7f18f_row10_col4, #T_7f18f_row10_col5, #T_7f18f_row10_col6, #T_7f18f_row11_col0, #T_7f18f_row11_col1, #T_7f18f_row11_col2, #T_7f18f_row11_col3, #T_7f18f_row11_col4, #T_7f18f_row11_col5, #T_7f18f_row11_col6, #T_7f18f_row12_col0, #T_7f18f_row12_col1, #T_7f18f_row12_col2, #T_7f18f_row12_col3, #T_7f18f_row12_col4, #T_7f18f_row12_col5, #T_7f18f_row12_col6, #T_7f18f_row13_col0, #T_7f18f_row13_col1, #T_7f18f_row13_col2, #T_7f18f_row13_col3, #T_7f18f_row13_col4, #T_7f18f_row13_col5, #T_7f18f_row13_col6, #T_7f18f_row14_col0, #T_7f18f_row14_col1, #T_7f18f_row14_col2, #T_7f18f_row14_col3, #T_7f18f_row14_col4, #T_7f18f_row14_col5, #T_7f18f_row14_col6, #T_7f18f_row15_col0, #T_7f18f_row15_col1, #T_7f18f_row15_col2, #T_7f18f_row15_col3, #T_7f18f_row15_col4, #T_7f18f_row15_col5, #T_7f18f_row15_col6, #T_7f18f_row16_col0, #T_7f18f_row16_col1, #T_7f18f_row16_col2, #T_7f18f_row16_col3, #T_7f18f_row16_col4, #T_7f18f_row16_col5, #T_7f18f_row16_col6, #T_7f18f_row17_col0, #T_7f18f_row17_col1, #T_7f18f_row17_col2, #T_7f18f_row17_col3, #T_7f18f_row17_col4, #T_7f18f_row17_col5, #T_7f18f_row17_col6, #T_7f18f_row18_col0, #T_7f18f_row18_col1, #T_7f18f_row18_col2, #T_7f18f_row18_col3, #T_7f18f_row18_col4, #T_7f18f_row18_col5, #T_7f18f_row18_col6, #T_7f18f_row19_col0, #T_7f18f_row19_col1, #T_7f18f_row19_col2, #T_7f18f_row19_col3, #T_7f18f_row19_col4, #T_7f18f_row19_col5, #T_7f18f_row19_col6, #T_7f18f_row20_col0, #T_7f18f_row20_col1, #T_7f18f_row20_col2, #T_7f18f_row20_col3, #T_7f18f_row20_col4, #T_7f18f_row20_col5, #T_7f18f_row20_col6, #T_7f18f_row21_col0, #T_7f18f_row21_col1, #T_7f18f_row21_col2, #T_7f18f_row21_col3, #T_7f18f_row21_col4, #T_7f18f_row21_col5, #T_7f18f_row21_col6, #T_7f18f_row22_col0, #T_7f18f_row22_col1, #T_7f18f_row22_col2, #T_7f18f_row22_col3, #T_7f18f_row22_col4, #T_7f18f_row22_col5, #T_7f18f_row22_col6, #T_7f18f_row23_col0, #T_7f18f_row23_col1, #T_7f18f_row23_col2, #T_7f18f_row23_col3, #T_7f18f_row23_col4, #T_7f18f_row23_col5, #T_7f18f_row23_col6, #T_7f18f_row24_col0, #T_7f18f_row24_col1, #T_7f18f_row24_col2, #T_7f18f_row24_col3, #T_7f18f_row24_col4, #T_7f18f_row24_col5, #T_7f18f_row24_col6, #T_7f18f_row25_col0, #T_7f18f_row25_col1, #T_7f18f_row25_col2, #T_7f18f_row25_col3, #T_7f18f_row25_col4, #T_7f18f_row25_col5, #T_7f18f_row25_col6, #T_7f18f_row26_col0, #T_7f18f_row26_col1, #T_7f18f_row26_col2, #T_7f18f_row26_col3, #T_7f18f_row26_col4, #T_7f18f_row26_col5, #T_7f18f_row26_col6, #T_7f18f_row27_col0, #T_7f18f_row27_col1, #T_7f18f_row27_col2, #T_7f18f_row27_col3, #T_7f18f_row27_co ...

# %% [markdown]
# # Copy the Constructed Circuit
#
# Copy the constructed circuit, so it does not have to be built again for later uses.
#
# ## Create a list of Quantum Circuit Instructions

# %%
mCircData = mCirc.data[digits:]
list(mCircData)
# Out:
# [CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 16)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 16),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 17)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 17),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 18)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 18),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 19)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 19),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 20)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 20),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 21)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 21),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 22)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 22),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 23)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 23),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 24)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 24),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 25)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 25),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 26)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 26),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 27)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 27),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 28)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 28),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 29)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 29),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 30)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 30),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 31)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 31),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 32)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 32),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 33)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 33),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=9, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 17), Qubit(QuantumRegister(80, 'q'), 18), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 34)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 34),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 35)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 35),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 36)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 36),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 37)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 37),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 38)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 38),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 39)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 39),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 40)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 40),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 41)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 41),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 18), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 42)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 42),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 18), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 43)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 43),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 44)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 44),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 45)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 45),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 46)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 46),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 47)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 47),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 48)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 48),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=7, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 49)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 49),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=7, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 50)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 50),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=7, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 51)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 51),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 52)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 52),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 53)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 53),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 54)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 54),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=6, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 55)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 55),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=6, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 56)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 56),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=6, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 57)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 57),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=6, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 58)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 58),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 59)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 59),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=5, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 60)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 60),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=5, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 61)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 61),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 62)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 62),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=5, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 63)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 63),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=5, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 64)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 64),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=5, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 65)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 65),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 66)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 66),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 67)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 67),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 68)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 68),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 69)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 69),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 70)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 70),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 71)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 71),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 72)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 72),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 73)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 73),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 74)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 74),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 75)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 75),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 76)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 76),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 77)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 77),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 78)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 78),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 79)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 79),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 24), Qubit(QuantumRegister(80, 'q'), 25), Qubit(QuantumRegister(80, 'q'), 26), Qubit(QuantumRegister(80, 'q'), 27), Qubit(QuantumRegister(80, 'q'), 28), Qubit(QuantumRegister(80, 'q'), 29), Qubit(QuantumRegister(80, 'q'), 30), Qubit(QuantumRegister(80, 'q'), 8)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 8),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 31), Qubit(QuantumRegister(80, 'q'), 32), Qubit(QuantumRegister(80, 'q'), 33), Qubit(QuantumRegister(80, 'q'), 34), Qubit(QuantumRegister(80, 'q'), 35), Qubit(QuantumRegister(80, 'q'), 36), Qubit(QuantumRegister(80, 'q'), 37), Qubit(QuantumRegister(80, 'q'), 9)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 9),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 38), Qubit(QuantumRegister(80, 'q'), 39), Qubit(QuantumRegister(80, 'q'), 40), Qubit(QuantumRegister(80, 'q'), 41), Qubit(QuantumRegister(80, 'q'), 42), Qubit(QuantumRegister(80, 'q'), 43), Qubit(QuantumRegister(80, 'q'), 44), Qubit(QuantumRegister(80, 'q'), 10)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 10),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 45), Qubit(QuantumRegister(80, 'q'), 46), Qubit(QuantumRegister(80, 'q'), 47), Qubit(QuantumRegister(80, 'q'), 48), Qubit(QuantumRegister(80, 'q'), 49), Qubit(QuantumRegister(80, 'q'), 50), Qubit(QuantumRegister(80, 'q'), 51), Qubit(QuantumRegister(80, 'q'), 11)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 11),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 52), Qubit(QuantumRegister(80, 'q'), 53), Qubit(QuantumRegister(80, 'q'), 54), Qubit(QuantumRegister(80, 'q'), 55), Qubit(QuantumRegister(80, 'q'), 56), Qubit(QuantumRegister(80, 'q'), 57), Qubit(QuantumRegister(80, 'q'), 58), Qubit(QuantumRegister(80, 'q'), 12)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 12),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 59), Qubit(QuantumRegister(80, 'q'), 60), Qubit(QuantumRegister(80, 'q'), 61), Qubit(QuantumRegister(80, 'q'), 62), Qubit(QuantumRegister(80, 'q'), 63), Qubit(QuantumRegister(80, 'q'), 64), Qubit(QuantumRegister(80, 'q'), 65), Qubit(QuantumRegister(80, 'q'), 13)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 13),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 66), Qubit(QuantumRegister(80, 'q'), 67), Qubit(QuantumRegister(80, 'q'), 68), Qubit(QuantumRegister(80, 'q'), 69), Qubit(QuantumRegister(80, 'q'), 70), Qubit(QuantumRegister(80, 'q'), 71), Qubit(QuantumRegister(80, 'q'), 72), Qubit(QuantumRegister(80, 'q'), 14)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 14),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 73), Qubit(QuantumRegister(80, 'q'), 74), Qubit(QuantumRegister(80, 'q'), 75), Qubit(QuantumRegister(80, 'q'), 76), Qubit(QuantumRegister(80, 'q'), 77), Qubit(QuantumRegister(80, 'q'), 78), Qubit(QuantumRegister(80, 'q'), 79), Qubit(QuantumRegister(80, 'q'), 15)), clbits=()),
#  CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 15),), clbits=()),
#  CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 8),), clbits=(Clbit(ClassicalRegister(8, 'c'), 7),)),
#  CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 9),), clbits=(Clbit(ClassicalRegister(8, 'c'), 6),)),
#  CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 10),), clbits=(Clbit(ClassicalRegister(8, 'c'), 5),)),
#  CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 11),), clbits=(Clbit(ClassicalRegister(8, 'c'), 4),)),
#  CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 12),), clbits=(Clbit(ClassicalRegister(8, 'c'), 3),)),
#  CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 13),), clbits=(Clbit(ClassicalRegister(8, 'c'), 2),)),
#  CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 14),), clbits=(Clbit(ClassicalRegister(8, 'c'), 1),)),
#  CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 15),), clbits=(Clbit(ClassicalRegister(8, 'c'), 0),))]

# %% [markdown]
# ## Print out Quantum Circuit Instructions along with Qubits involved

# %%
for mCircDataCont in mCircData:
    print(mCircDataCont, mCircDataCont.qubits, sep='\t')
# Out:
# CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 16)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 16))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 16),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 16),)
# CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 17)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 17))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 17),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 17),)
# CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 18)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 18))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 18),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 18),)
# CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 19)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 19))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 19),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 19),)
# CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 20)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 20))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 20),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 20),)
# CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 21)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 21))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 21),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 21),)
# CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 22)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 22))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 22),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 22),)
# CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 23)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 23))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 23),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 23),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 24)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 24))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 24),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 24),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 25)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 25))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 25),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 25),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 26)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 26))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 26),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 26),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 27)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 27))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 27),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 27),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 28)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 28))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 28),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 28),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 29)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 29))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 29),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 29),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 30)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 30))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 30),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 30),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 31)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 31))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 31),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 31),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 32)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 32))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 32),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 32),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 33)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 33))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 33),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 33),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=9, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 17), Qubit(QuantumRegister(80, 'q'), 18), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 34)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 17), Qubit(QuantumRegister(80, 'q'), 18), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 34))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 34),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 34),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 35)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 35))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 35),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 35),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 36)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 36))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 36),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 36),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 37)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 37))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 37),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 37),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 38)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 38))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 38),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 38),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 39)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 39))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 39),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 39),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 40)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 40))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 40),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 40),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 41)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 41))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 41),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 41),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 18), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 42)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 18), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 42))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 42),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 42),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 18), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 43)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 18), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 43))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 43),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 43),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 44)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 44))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 44),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 44),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 45)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 45))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 45),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 45),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 46)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 46))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 46),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 46),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 47)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 47))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 47),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 47),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 48)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 48))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 48),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 48),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=7, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 49)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 49))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 49),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 49),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=7, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 50)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 50))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 50),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 50),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=7, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 51)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 19), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 51))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 51),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 51),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 52)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 52))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 52),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 52),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 53)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 53))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 53),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 53),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 54)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 54))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 54),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 54),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=6, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 55)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 55))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 55),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 55),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=6, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 56)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 56))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 56),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 56),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=6, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 57)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 57))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 57),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 57),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=6, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 58)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 20), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 58))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 58),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 58),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 59)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 59))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 59),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 59),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=5, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 60)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 60))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 60),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 60),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=5, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 61)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 61))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 61),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 61),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 62)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 62))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 62),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 62),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=5, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 63)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 63))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 63),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 63),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=5, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 64)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 64))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 64),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 64),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=5, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 65)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 21), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 65))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 65),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 65),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 66)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 66))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 66),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 66),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 67)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 67))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 67),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 67),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 68)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 68))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 68),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 68),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 69)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 69))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 69),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 69),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 70)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 7), Qubit(QuantumRegister(80, 'q'), 70))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 70),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 70),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 71)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 71))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 71),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 71),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=4, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 72)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 22), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 72))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 72),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 72),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 73)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 1), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 73))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 73),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 73),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 74)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 3), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 74))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 74),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 74),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 75)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 4), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 75))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 75),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 75),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 76)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 5), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 76))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 76),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 76),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 77)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 0), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 77))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 77),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 77),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 78)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 2), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 78))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 78),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 78),)
# CircuitInstruction(operation=Instruction(name='ccx', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 79)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 6), Qubit(QuantumRegister(80, 'q'), 23), Qubit(QuantumRegister(80, 'q'), 79))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 79),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 79),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 24), Qubit(QuantumRegister(80, 'q'), 25), Qubit(QuantumRegister(80, 'q'), 26), Qubit(QuantumRegister(80, 'q'), 27), Qubit(QuantumRegister(80, 'q'), 28), Qubit(QuantumRegister(80, 'q'), 29), Qubit(QuantumRegister(80, 'q'), 30), Qubit(QuantumRegister(80, 'q'), 8)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 24), Qubit(QuantumRegister(80, 'q'), 25), Qubit(QuantumRegister(80, 'q'), 26), Qubit(QuantumRegister(80, 'q'), 27), Qubit(QuantumRegister(80, 'q'), 28), Qubit(QuantumRegister(80, 'q'), 29), Qubit(QuantumRegister(80, 'q'), 30), Qubit(QuantumRegister(80, 'q'), 8))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 8),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 8),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 31), Qubit(QuantumRegister(80, 'q'), 32), Qubit(QuantumRegister(80, 'q'), 33), Qubit(QuantumRegister(80, 'q'), 34), Qubit(QuantumRegister(80, 'q'), 35), Qubit(QuantumRegister(80, 'q'), 36), Qubit(QuantumRegister(80, 'q'), 37), Qubit(QuantumRegister(80, 'q'), 9)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 31), Qubit(QuantumRegister(80, 'q'), 32), Qubit(QuantumRegister(80, 'q'), 33), Qubit(QuantumRegister(80, 'q'), 34), Qubit(QuantumRegister(80, 'q'), 35), Qubit(QuantumRegister(80, 'q'), 36), Qubit(QuantumRegister(80, 'q'), 37), Qubit(QuantumRegister(80, 'q'), 9))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 9),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 9),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 38), Qubit(QuantumRegister(80, 'q'), 39), Qubit(QuantumRegister(80, 'q'), 40), Qubit(QuantumRegister(80, 'q'), 41), Qubit(QuantumRegister(80, 'q'), 42), Qubit(QuantumRegister(80, 'q'), 43), Qubit(QuantumRegister(80, 'q'), 44), Qubit(QuantumRegister(80, 'q'), 10)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 38), Qubit(QuantumRegister(80, 'q'), 39), Qubit(QuantumRegister(80, 'q'), 40), Qubit(QuantumRegister(80, 'q'), 41), Qubit(QuantumRegister(80, 'q'), 42), Qubit(QuantumRegister(80, 'q'), 43), Qubit(QuantumRegister(80, 'q'), 44), Qubit(QuantumRegister(80, 'q'), 10))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 10),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 10),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 45), Qubit(QuantumRegister(80, 'q'), 46), Qubit(QuantumRegister(80, 'q'), 47), Qubit(QuantumRegister(80, 'q'), 48), Qubit(QuantumRegister(80, 'q'), 49), Qubit(QuantumRegister(80, 'q'), 50), Qubit(QuantumRegister(80, 'q'), 51), Qubit(QuantumRegister(80, 'q'), 11)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 45), Qubit(QuantumRegister(80, 'q'), 46), Qubit(QuantumRegister(80, 'q'), 47), Qubit(QuantumRegister(80, 'q'), 48), Qubit(QuantumRegister(80, 'q'), 49), Qubit(QuantumRegister(80, 'q'), 50), Qubit(QuantumRegister(80, 'q'), 51), Qubit(QuantumRegister(80, 'q'), 11))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 11),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 11),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 52), Qubit(QuantumRegister(80, 'q'), 53), Qubit(QuantumRegister(80, 'q'), 54), Qubit(QuantumRegister(80, 'q'), 55), Qubit(QuantumRegister(80, 'q'), 56), Qubit(QuantumRegister(80, 'q'), 57), Qubit(QuantumRegister(80, 'q'), 58), Qubit(QuantumRegister(80, 'q'), 12)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 52), Qubit(QuantumRegister(80, 'q'), 53), Qubit(QuantumRegister(80, 'q'), 54), Qubit(QuantumRegister(80, 'q'), 55), Qubit(QuantumRegister(80, 'q'), 56), Qubit(QuantumRegister(80, 'q'), 57), Qubit(QuantumRegister(80, 'q'), 58), Qubit(QuantumRegister(80, 'q'), 12))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 12),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 12),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 59), Qubit(QuantumRegister(80, 'q'), 60), Qubit(QuantumRegister(80, 'q'), 61), Qubit(QuantumRegister(80, 'q'), 62), Qubit(QuantumRegister(80, 'q'), 63), Qubit(QuantumRegister(80, 'q'), 64), Qubit(QuantumRegister(80, 'q'), 65), Qubit(QuantumRegister(80, 'q'), 13)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 59), Qubit(QuantumRegister(80, 'q'), 60), Qubit(QuantumRegister(80, 'q'), 61), Qubit(QuantumRegister(80, 'q'), 62), Qubit(QuantumRegister(80, 'q'), 63), Qubit(QuantumRegister(80, 'q'), 64), Qubit(QuantumRegister(80, 'q'), 65), Qubit(QuantumRegister(80, 'q'), 13))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 13),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 13),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 66), Qubit(QuantumRegister(80, 'q'), 67), Qubit(QuantumRegister(80, 'q'), 68), Qubit(QuantumRegister(80, 'q'), 69), Qubit(QuantumRegister(80, 'q'), 70), Qubit(QuantumRegister(80, 'q'), 71), Qubit(QuantumRegister(80, 'q'), 72), Qubit(QuantumRegister(80, 'q'), 14)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 66), Qubit(QuantumRegister(80, 'q'), 67), Qubit(QuantumRegister(80, 'q'), 68), Qubit(QuantumRegister(80, 'q'), 69), Qubit(QuantumRegister(80, 'q'), 70), Qubit(QuantumRegister(80, 'q'), 71), Qubit(QuantumRegister(80, 'q'), 72), Qubit(QuantumRegister(80, 'q'), 14))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 14),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 14),)
# CircuitInstruction(operation=Instruction(name='mcx', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 73), Qubit(QuantumRegister(80, 'q'), 74), Qubit(QuantumRegister(80, 'q'), 75), Qubit(QuantumRegister(80, 'q'), 76), Qubit(QuantumRegister(80, 'q'), 77), Qubit(QuantumRegister(80, 'q'), 78), Qubit(QuantumRegister(80, 'q'), 79), Qubit(QuantumRegister(80, 'q'), 15)), clbits=())	(Qubit(QuantumRegister(80, 'q'), 73), Qubit(QuantumRegister(80, 'q'), 74), Qubit(QuantumRegister(80, 'q'), 75), Qubit(QuantumRegister(80, 'q'), 76), Qubit(QuantumRegister(80, 'q'), 77), Qubit(QuantumRegister(80, 'q'), 78), Qubit(QuantumRegister(80, 'q'), 79), Qubit(QuantumRegister(80, 'q'), 15))
# CircuitInstruction(operation=Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 15),), clbits=())	(Qubit(QuantumRegister(80, 'q'), 15),)
# CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 8),), clbits=(Clbit(ClassicalRegister(8, 'c'), 7),))	(Qubit(QuantumRegister(80, 'q'), 8),)
# CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 9),), clbits=(Clbit(ClassicalRegister(8, 'c'), 6),))	(Qubit(QuantumRegister(80, 'q'), 9),)
# CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 10),), clbits=(Clbit(ClassicalRegister(8, 'c'), 5),))	(Qubit(QuantumRegister(80, 'q'), 10),)
# CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 11),), clbits=(Clbit(ClassicalRegister(8, 'c'), 4),))	(Qubit(QuantumRegister(80, 'q'), 11),)
# CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 12),), clbits=(Clbit(ClassicalRegister(8, 'c'), 3),))	(Qubit(QuantumRegister(80, 'q'), 12),)
# CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 13),), clbits=(Clbit(ClassicalRegister(8, 'c'), 2),))	(Qubit(QuantumRegister(80, 'q'), 13),)
# CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 14),), clbits=(Clbit(ClassicalRegister(8, 'c'), 1),))	(Qubit(QuantumRegister(80, 'q'), 14),)
# CircuitInstruction(operation=Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), qubits=(Qubit(QuantumRegister(80, 'q'), 15),), clbits=(Clbit(ClassicalRegister(8, 'c'), 0),))	(Qubit(QuantumRegister(80, 'q'), 15),)

# %% [markdown]
# ## Check attributes of a single qubit

# %%
dir(mCircDataCont.qubits[0])
# Out:
# ['__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_hash',
#  '_index',
#  '_register',
#  '_repr',
#  'index',
#  'register']

# %% [markdown]
# ## List out the Gates utilized along with the Qubits invovled

# %%
for mCircDataCont in mCircData:
    operationName = mCircDataCont.operation.name
    qubits = [qubit.index for qubit in mCircDataCont.qubits]
    
    if operationName == 'measure':
        print(operationName, qubits, mCircDataCont.clbits[0].index, sep='\t\t')
        
    else:
        print(operationName, qubits, sep='\t\t')
# Out:
# cx		[0, 16]
# x		[16]
# cx		[1, 17]
# x		[17]
# cx		[2, 18]
# x		[18]
# cx		[3, 19]
# x		[19]
# cx		[4, 20]
# x		[20]
# cx		[5, 21]
# x		[21]
# cx		[6, 22]
# x		[22]
# cx		[7, 23]
# x		[23]
# ccx		[0, 3, 24]
# x		[24]
# ccx		[0, 5, 25]
# x		[25]
# ccx		[0, 2, 26]
# x		[26]
# ccx		[0, 6, 27]
# x		[27]
# ccx		[0, 4, 28]
# x		[28]
# ccx		[0, 7, 29]
# x		[29]
# ccx		[0, 1, 30]
# x		[30]
# ccx		[1, 6, 31]
# x		[31]
# ccx		[1, 4, 32]
# x		[32]
# ccx		[1, 7, 33]
# x		[33]
# mcx		[0, 17, 18, 19, 20, 21, 22, 23, 34]
# x		[34]
# ccx		[1, 2, 35]
# x		[35]
# ccx		[1, 3, 36]
# x		[36]
# ccx		[1, 5, 37]
# x		[37]
# ccx		[2, 5, 38]
# x		[38]
# ccx		[2, 6, 39]
# x		[39]
# ccx		[2, 4, 40]
# x		[40]
# ccx		[2, 7, 41]
# x		[41]
# mcx		[1, 18, 19, 20, 21, 22, 23, 42]
# x		[42]
# mcx		[0, 18, 19, 20, 21, 22, 23, 43]
# x		[43]
# ccx		[2, 3, 44]
# x		[44]
# ccx		[3, 5, 45]
# x		[45]
# ccx		[3, 6, 46]
# x		[46]
# ccx		[3, 4, 47]
# x		[47]
# ccx		[3, 7, 48]
# x		[48]
# mcx		[0, 19, 20, 21, 22, 23, 49]
# x		[49]
# mcx		[1, 19, 20, 21, 22, 23, 50]
# x		[50]
# mcx		[2, 19, 20, 21, 22, 23, 51]
# x		[51]
# ccx		[4, 5, 52]
# x		[52]
# ccx		[4, 6, 53]
# x		[53]
# ccx		[4, 7, 54]
# x		[54]
# mcx		[3, 20, 21, 22, 23, 55]
# x		[55]
# mcx		[1, 20, 21, 22, 23, 56]
# x		[56]
# mcx		[2, 20, 21, 22, 23, 57]
# x		[57]
# mcx		[0, 20, 21, 22, 23, 58]
# x		[58]
# ccx		[5, 6, 59]
# x		[59]
# mcx		[1, 21, 22, 23, 60]
# x		[60]
# mcx		[3, 21, 22, 23, 61]
# x		[61]
# ccx		[5, 7, 62]
# x		[62]
# mcx		[2, 21, 22, 23, 63]
# x		[63]
# mcx		[4, 21, 22, 23, 64]
# x		[64]
# mcx		[0, 21, 22, 23, 65]
# x		[65]
# mcx		[1, 22, 23, 66]
# x		[66]
# mcx		[3, 22, 23, 67]
# x		[67]
# mcx		[2, 22, 23, 68]
# x		[68]
# mcx		[5, 22, 23, 69]
# x		[69]
# ccx		[6, 7, 70]
# x		[70]
# mcx		[0, 22, 23, 71]
# x		[71]
# mcx		[4, 22, 23, 72]
# x		[72]
# ccx		[1, 23, 73]
# x		[73]
# ccx		[3, 23, 74]
# x		[74]
# ccx		[4, 23, 75]
# x		[75]
# ccx		[5, 23, 76]
# x		[76]
# ccx		[0, 23, 77]
# x		[77]
# ccx		[2, 23, 78]
# x		[78]
# ccx		[6, 23, 79]
# x		[79]
# mcx		[24, 25, 26, 27, 28, 29, 30, 8]
# x		[8]
# mcx		[31, 32, 33, 34, 35, 36, 37, 9]
# x		[9]
# mcx		[38, 39, 40, 41, 42, 43, 44, 10]
# x		[10]
# mcx		[45, 46, 47, 48, 49, 50, 51, 11]
# x		[11]
# mcx		[52, 53, 54, 55, 56, 57, 58, 12]
# x		[12]
# mcx		[59, 60, 61, 62, 63, 64, 65, 13]
# x		[13]
# mcx		[66, 67, 68, 69, 70, 71, 72, 14]
# x		[14]
# mcx		[73, 74, 75, 76, 77, 78, 79, 15]
# x		[15]
# measure		[8]		7
# measure		[9]		6
# measure		[10]		5
# measure		[11]		4
# measure		[12]		3
# measure		[13]		2
# measure		[14]		1
# measure		[15]		0
# C:\Users\mulia\AppData\Local\Temp\ipykernel_39068\3623839334.py:3: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   qubits = [qubit.index for qubit in mCircDataCont.qubits]
# C:\Users\mulia\AppData\Local\Temp\ipykernel_39068\3623839334.py:6: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   print(operationName, qubits, mCircDataCont.clbits[0].index, sep='\t\t')

# %% [markdown]
# ## Ready for Implementations
#
# Finally, it is ready for implementations. Copy and paste this into another Python program or Jupyter Notebook.
#
# There would be an example for that: <a href='Multiplication Calculator (2-bit Inputs).ipynb'>Quantum Multiplication Calculator (2-bit Inputs)</a>

# %%
print(f'mCirc = QuantumCircuit({qubitNums}, {digits})', end='\n\n')

for mCircDataCont in mCircData:
    operationName = mCircDataCont.operation.name
    qubits = [qubit.index for qubit in mCircDataCont.qubits]
    
    if operationName == 'measure':
        print(f'mCirc.measure({qubits}, [{mCircDataCont.clbits[0].index}])')
        
    elif operationName == 'mcx':
        print(f'mCirc.append({operationName.upper()}Gate(num_ctrl_qubits={len(qubits)-1}), {qubits})')
        
    else:
        print(f'mCirc.append({operationName.upper()}Gate(), {qubits})')
# Out:
# mCirc = QuantumCircuit(80, 8)
#
# mCirc.append(CXGate(), [0, 16])
# mCirc.append(XGate(), [16])
# mCirc.append(CXGate(), [1, 17])
# mCirc.append(XGate(), [17])
# mCirc.append(CXGate(), [2, 18])
# mCirc.append(XGate(), [18])
# mCirc.append(CXGate(), [3, 19])
# mCirc.append(XGate(), [19])
# mCirc.append(CXGate(), [4, 20])
# mCirc.append(XGate(), [20])
# mCirc.append(CXGate(), [5, 21])
# mCirc.append(XGate(), [21])
# mCirc.append(CXGate(), [6, 22])
# mCirc.append(XGate(), [22])
# mCirc.append(CXGate(), [7, 23])
# mCirc.append(XGate(), [23])
# mCirc.append(CCXGate(), [0, 3, 24])
# mCirc.append(XGate(), [24])
# mCirc.append(CCXGate(), [0, 5, 25])
# mCirc.append(XGate(), [25])
# mCirc.append(CCXGate(), [0, 2, 26])
# mCirc.append(XGate(), [26])
# mCirc.append(CCXGate(), [0, 6, 27])
# mCirc.append(XGate(), [27])
# mCirc.append(CCXGate(), [0, 4, 28])
# mCirc.append(XGate(), [28])
# mCirc.append(CCXGate(), [0, 7, 29])
# mCirc.append(XGate(), [29])
# mCirc.append(CCXGate(), [0, 1, 30])
# mCirc.append(XGate(), [30])
# mCirc.append(CCXGate(), [1, 6, 31])
# mCirc.append(XGate(), [31])
# mCirc.append(CCXGate(), [1, 4, 32])
# mCirc.append(XGate(), [32])
# mCirc.append(CCXGate(), [1, 7, 33])
# mCirc.append(XGate(), [33])
# mCirc.append(MCXGate(num_ctrl_qubits=8), [0, 17, 18, 19, 20, 21, 22, 23, 34])
# mCirc.append(XGate(), [34])
# mCirc.append(CCXGate(), [1, 2, 35])
# mCirc.append(XGate(), [35])
# mCirc.append(CCXGate(), [1, 3, 36])
# mCirc.append(XGate(), [36])
# mCirc.append(CCXGate(), [1, 5, 37])
# mCirc.append(XGate(), [37])
# mCirc.append(CCXGate(), [2, 5, 38])
# mCirc.append(XGate(), [38])
# mCirc.append(CCXGate(), [2, 6, 39])
# mCirc.append(XGate(), [39])
# mCirc.append(CCXGate(), [2, 4, 40])
# mCirc.append(XGate(), [40])
# mCirc.append(CCXGate(), [2, 7, 41])
# mCirc.append(XGate(), [41])
# mCirc.append(MCXGate(num_ctrl_qubits=7), [1, 18, 19, 20, 21, 22, 23, 42])
# mCirc.append(XGate(), [42])
# mCirc.append(MCXGate(num_ctrl_qubits=7), [0, 18, 19, 20, 21, 22, 23, 43])
# mCirc.append(XGate(), [43])
# mCirc.append(CCXGate(), [2, 3, 44])
# mCirc.append(XGate(), [44])
# mCirc.append(CCXGate(), [3, 5, 45])
# mCirc.append(XGate(), [45])
# mCirc.append(CCXGate(), [3, 6, 46])
# mCirc.append(XGate(), [46])
# mCirc.append(CCXGate(), [3, 4, 47])
# mCirc.append(XGate(), [47])
# mCirc.append(CCXGate(), [3, 7, 48])
# mCirc.append(XGate(), [48])
# mCirc.append(MCXGate(num_ctrl_qubits=6), [0, 19, 20, 21, 22, 23, 49])
# mCirc.append(XGate(), [49])
# mCirc.append(MCXGate(num_ctrl_qubits=6), [1, 19, 20, 21, 22, 23, 50])
# mCirc.append(XGate(), [50])
# mCirc.append(MCXGate(num_ctrl_qubits=6), [2, 19, 20, 21, 22, 23, 51])
# mCirc.append(XGate(), [51])
# mCirc.append(CCXGate(), [4, 5, 52])
# mCirc.append(XGate(), [52])
# mCirc.append(CCXGate(), [4, 6, 53])
# mCirc.append(XGate(), [53])
# mCirc.append(CCXGate(), [4, 7, 54])
# mCirc.append(XGate(), [54])
# mCirc.append(MCXGate(num_ctrl_qubits=5), [3, 20, 21, 22, 23, 55])
# mCirc.append(XGate(), [55])
# mCirc.append(MCXGate(num_ctrl_qubits=5), [1, 20, 21, 22, 23, 56])
# mCirc.append(XGate(), [56])
# mCirc.append(MCXGate(num_ctrl_qubits=5), [2, 20, 21, 22, 23, 57])
# mCirc.append(XGate(), [57])
# mCirc.append(MCXGate(num_ctrl_qubits=5), [0, 20, 21, 22, 23, 58])
# mCirc.append(XGate(), [58])
# mCirc.append(CCXGate(), [5, 6, 59])
# mCirc.append(XGate(), [59])
# mCirc.append(MCXGate(num_ctrl_qubits=4), [1, 21, 22, 23, 60])
# mCirc.append(XGate(), [60])
# mCirc.append(MCXGate(num_ctrl_qubits=4), [3, 21, 22, 23, 61])
# mCirc.append(XGate(), [61])
# mCirc.append(CCXGate(), [5, 7, 62])
# mCirc.append(XGate(), [62])
# mCirc.append(MCXGate(num_ctrl_qubits=4), [2, 21, 22, 23, 63])
# mCirc.append(XGate(), [63])
# mCirc.append(MCXGate(num_ctrl_qubits=4), [4, 21, 22, 23, 64])
# mCirc.append(XGate(), [64])
# mCirc.append(MCXGate(num_ctrl_qubits=4), [0, 21, 22, 23, 65])
# mCirc.append(XGate(), [65])
# mCirc.append(MCXGate(num_ctrl_qubits=3), [1, 22, 23, 66])
# mCirc.append(XGate(), [66])
# mCirc.append(MCXGate(num_ctrl_qubits=3), [3, 22, 23, 67])
# mCirc.append(XGate(), [67])
# mCirc.append(MCXGate(num_ctrl_qubits=3), [2, 22, 23, 68])
# mCirc.append(XGate(), [68])
# mCirc.append(MCXGate(num_ctrl_qubits=3), [5, 22, 23, 69])
# mCirc.append(XGate(), [69])
# mCirc.append(CCXGate(), [6, 7, 70])
# mCirc.append(XGate(), [70])
# mCirc.append(MCXGate(num_ctrl_qubits=3), [0, 22, 23, 71])
# mCirc.append(XGate(), [71])
# mCirc.append(MCXGate(num_ctrl_qubits=3), [4, 22, 23, 72])
# mCirc.append(XGate(), [72])
# mCirc.append(CCXGate(), [1, 23, 73])
# mCirc.append(XGate(), [73])
# mCirc.append(CCXGate(), [3, 23, 74])
# mCirc.append(XGate(), [74])
# mCirc.append(CCXGate(), [4, 23, 75])
# mCirc.append(XGate(), [75])
# mCirc.append(CCXGate(), [5, 23, 76])
# mCirc.append(XGate(), [76])
# mCirc.append(CCXGate(), [0, 23, 77])
# mCirc.append(XGate(), [77])
# mCirc.append(CCXGate(), [2, 23, 78])
# mCirc.append(XGate(), [78])
# mCirc.append(CCXGate(), [6, 23, 79])
# mCirc.append(XGate(), [79])
# mCirc.append(MCXGate(num_ctrl_qubits=7), [24, 25, 26, 27, 28, 29, 30, 8])
# mCirc.append(XGate(), [8])
# mCirc.append(MCXGate(num_ctrl_qubits=7), [31, 32, 33, 34, 35, 36, 37, 9])
# mCirc.append(XGate(), [9])
# mCirc.append(MCXGate(num_ctrl_qubits=7), [38, 39, 40, 41, 42, 43, 44, 10])
# mCirc.append(XGate(), [10])
# mCirc.append(MCXGate(num_ctrl_qubits=7), [45, 46, 47, 48, 49, 50, 51, 11])
# mCirc.append(XGate(), [11])
# mCirc.append(MCXGate(num_ctrl_qubits=7), [52, 53, 54, 55, 56, 57, 58, 12])
# mCirc.append(XGate(), [12])
# mCirc.append(MCXGate(num_ctrl_qubits=7), [59, 60, 61, 62, 63, 64, 65, 13])
# mCirc.append(XGate(), [13])
# mCirc.append(MCXGate(num_ctrl_qubits=7), [66, 67, 68, 69, 70, 71, 72, 14])
# mCirc.append(XGate(), [14])
# mCirc.append(MCXGate(num_ctrl_qubits=7), [73, 74, 75, 76, 77, 78, 79, 15])
# mCirc.append(XGate(), [15])
# mCirc.measure([8], [7])
# mCirc.measure([9], [6])
# mCirc.measure([10], [5])
# mCirc.measure([11], [4])
# mCirc.measure([12], [3])
# mCirc.measure([13], [2])
# mCirc.measure([14], [1])
# mCirc.measure([15], [0])
# C:\Users\mulia\AppData\Local\Temp\ipykernel_39068\2646588482.py:5: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   qubits = [qubit.index for qubit in mCircDataCont.qubits]
# C:\Users\mulia\AppData\Local\Temp\ipykernel_39068\2646588482.py:8: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   print(f'mCirc.measure({qubits}, [{mCircDataCont.clbits[0].index}])')
